# %% [markdown]
# # Central Limit Theorem Example

# %% [markdown]
# ## Import and Load the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
population= pd.read_csv('employee_salary.csv')
population
# Out:
#       Department                               Department Name  \
# 0            BOA                   Board of Appeals Department
# 1            BOA                   Board of Appeals Department
# 2            BOA                   Board of Appeals Department
# 3            BOE                            Board of Elections
# 4            BOE                            Board of Elections
# ...          ...                                           ...
# 10100        SHF                              Sheriff's Office
# 10101        ZAH  Office of Zoning and Administrative Hearings
# 10102        ZAH  Office of Zoning and Administrative Hearings
# 10103        ZAH  Office of Zoning and Administrative Hearings
# 10104        ZAH  Office of Zoning and Administrative Hearings
#
#                                            Division Gender  Base Salary  \
# 0                         Board of Appeals Division      F     78902.00
# 1                         Board of Appeals Division      F     58481.91
# 2                                Executive Director      F    144751.00
# 3                                          Director      F    183654.18
# 4                          Polling Place Management      F     62488.00
# ...                                             ...    ...          ...
# 10100                                Administration      M     92217.23
# 10101                                      Director      M    179523.00
# 10102            Zoning and Administrative Hearings      F     90848.00
# 10103            Zoning and Administrative Hearings      F    170707.00
# 10104  Office of Zoning and Administrative Hearings      F     67034.05
#
#        2019 Overtime Pay  2019 Longevity Pay Grade
# 0                    0.0                 0.0    18
# 1                    0.0                 0.0    16
# 2                    0.0                 0.0    M3
# 3                    0.0                 0.0    M1
# 4                    0.0                 0.0    13
# ...                  ...                 ...   ...
# 10100                0.0                 0.0    26
# 10101                0.0                 0.0     0
# 10102                0.0                 0.0    21
# 10103                0.0                 0.0    35
# 10104                0.0                 0.0    18
#
# [10105 rows x 8 columns]

# %% [markdown]
# ## Dataset Information

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10105 entries, 0 to 10104
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Department          10105 non-null  object
#  1   Department Name     10105 non-null  object
#  2   Division            10105 non-null  object
#  3   Gender              10105 non-null  object
#  4   Base Salary         10105 non-null  float64
#  5   2019 Overtime Pay   10105 non-null  float64
#  6   2019 Longevity Pay  10105 non-null  float64
#  7   Grade               10105 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 631.7+ KB

# %% [markdown]
# For understanding CLT, we will just concentrate on the "Base Salary" column and call it the salary of the entire population.

# %%
population_base_salary = population['Base Salary']

# %%
population_base_salary
# Out:
# 0         78902.00
# 1         58481.91
# 2        144751.00
# 3        183654.18
# 4         62488.00
#            ...
# 10100     92217.23
# 10101    179523.00
# 10102     90848.00
# 10103    170707.00
# 10104     67034.05
# Name: Base Salary, Length: 10105, dtype: float64

# %% [markdown]
# ## Calulate the Population Mean and Plot Distribution Curve

# %%
print("Population Mean")
print("---------------")
print(population_base_salary.mean())
sns.distplot(population_base_salary, color='grey')
plt.xlabel('Population Base Salary')
plt.ylabel('Probability Density')
# Out:
# Population Mean
# ---------------
# 78936.02023948576
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# The above figure shows that the distribution is slightly asymmetric i.e. does not exactly follow the Gaussian Distribution.

# %% [markdown]
# ## Function to calculate sample means based on sample size

# %%
mean = []
def calc_sample_mean(sample_size, no_of_sample_means):
    for i in range(no_of_sample_means):        
        sample_base_salary = population_base_salary.sample(n=sample_size)
        sample_mean=sample_base_salary.mean()
        mean.append(sample_mean)
    return mean

# %% [markdown]
# ### Distribution Curve with sample size 2

# %%
mean_2=calc_sample_mean(sample_size=2, no_of_sample_means=500)
sns.distplot(mean_2, color='b')
plt.xlabel('Sample Base Salary Mean (Sample size =2)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# We got a Gaussian/Normal Distribution curve with slight skewness.

# %% [markdown]
# ### Distribution Curve with sample size 3

# %%
mean_3=calc_sample_mean(sample_size=3, no_of_sample_means=500)
sns.distplot(mean_3, color='r')
plt.xlabel('Sample Base Salary Mean (Sample size =3)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Distribution Curve with sample size 10

# %%
mean_10=calc_sample_mean(sample_size=10, no_of_sample_means=500)
sns.distplot(mean_10, color='y')
plt.xlabel('Sample Base Salary Mean (Sample size =10)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Distribution Curve with sample size 20

# %%
mean_20=calc_sample_mean(sample_size=20, no_of_sample_means=500)
sns.distplot(mean_20, color='g')
plt.xlabel('Sample Base Salary Mean (Sample size =20)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Distribution Curve with sample size 30

# %%
mean_30=calc_sample_mean(sample_size=30, no_of_sample_means=500)
sns.distplot(mean_30, color='maroon')
plt.xlabel('Sample Base Salary Mean (Sample size =30)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Distribution Curve with sample size 40

# %%
mean_40=calc_sample_mean(sample_size=40, no_of_sample_means=500)
sns.distplot(mean_40, color='pink')
plt.xlabel('Sample Base Salary Mean (Sample size =40)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Distribution Curve with sample size 100

# %%
mean_100=calc_sample_mean(sample_size=100, no_of_sample_means=500)
sns.distplot(mean_100, color='magenta')
plt.xlabel('Sample Base Salary Mean (Sample size =100)')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# As we increased the sample size, the skewness reduced and the curve became sharper.
#
# Sample sizes equal to or greater than 30 are considered sufficient for the theorem to hold true but that might not be always necessary.
#
# In our example, we can observe that we get a Gaussian Distribution with a sample size of 10 or 20  too.
#
# This shows that no matter what our population distribution curve is, the sample means will always follow Gaussian (Normal) Distribution.
